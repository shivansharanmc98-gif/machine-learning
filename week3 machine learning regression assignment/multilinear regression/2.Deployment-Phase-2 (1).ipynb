# %%
#loading and saving the model using pickel
import pickle

# %%
impoting pickle and saving the model in name of  finalized_model_Mul_linear.sav

# %%
loaded_model=pickle.load(open("finalized_model_Mul_linear.sav",'rb'))
result=loaded_model.predict([[2344,345,435,0,1]])
# Out:
# C:\Users\sharan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
loading the file finalized_model_Mul_linear.sav pickel

# %%
result
# Out:
# array([[44586.30936555]])

# %%
loading the result

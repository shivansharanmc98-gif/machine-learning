# %%
import pickle

# %%
experience_salary=int(input("enter the years of experience"))
# Out:
# enter the years of experience 0

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[experience_salary]])
# Out:
# C:\Users\sharan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
